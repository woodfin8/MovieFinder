# %%
import requests
import json
import pandas as pd
import numpy as np
from config2 import omdb_key
import warnings
from pprint import pprint
import re
warnings.filterwarnings('ignore')

# %%
movies = ["Alien", "Batman", "Blade Runner", "Crash", "blackkklansman"]

# %%
movie_jsons = []
url1 = "http://www.omdbapi.com/?t="
url2 = "&apikey="

# %%
for movie in movies:
    url = url1 + movie + url2 + omdb_key
    response = requests.get(url)
    print(response)
    response = response.json()
    movie_jsons.append(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# movie_jsons
# Out:
# [{'Title': 'Alien',
#   'Year': '1979',
#   'Rated': 'R',
#   'Released': '22 Jun 1979',
#   'Runtime': '117 min',
#   'Genre': 'Horror, Sci-Fi',
#   'Director': 'Ridley Scott',
#   'Writer': "Dan O'Bannon (screenplay by), Dan O'Bannon (story by), Ronald Shusett (story by)",
#   'Actors': 'Tom Skerritt, Sigourney Weaver, Veronica Cartwright, Harry Dean Stanton',
#   'Plot': 'After a space merchant vessel perceives an unknown transmission as a distress call, its landing on the source moon finds one of the crew attacked by a mysterious lifeform, and they soon realize that its life cycle has merely begun.',
#   'Language': 'English',
#   'Country': 'UK, USA',
#   'Awards': 'Won 1 Oscar. Another 16 wins & 19 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMmQ2MmU3NzktZjAxOC00ZDZhLTk4YzEtMDMyMzcxY2IwMDAyXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#    {'Source': 'Metacritic', 'Value': '89/100'}],
#   'Metascore': '89',
#   'imdbRating': '8.4',
#   'imdbVotes': '734,400',
#   'imdbID': 'tt0078748',
#   'Type': 'movie',
#   'DVD': '06 Jan 2004',
#   'BoxOffice': 'N/A',
#   'Production': '20th Century Fox',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Batman',
#   'Year': '1989',
#   'Rated': 'PG-13',
#   'Released': '23 Jun 1989',
#   'Runtime': '126 min',
#   'Genre': 'Action, Adventure',
#   'Director': 'Tim Burton',
#   'Writer': 'Bob Kane (Batman characters), Sam Hamm (story), Sam Hamm (screenplay), Warren Skaaren (screenplay)',
#   'Actors': 'Michael Keaton, Jack Nicholson, Kim Basinger, Robert Wuhl',
#   'Plot': 'The Dark Knight of Gotham City begins his war on crime with his first major enemy being the clownishly homicidal Joker.',
#   'Language': 'English, French, Spanish',
#   'Country': 'USA, UK',
#   'Awards': 'Won 1 Oscar. Another 8 wins & 26 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYwNjAyODIyMF5BMl5BanBnXkFtZTYwNDMwMDk2._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '69/100'}],
#   'Metascore': '69',
#   'imdbRating': '7.5',
#   'imdbVotes': '321,168',
#   'imdbID': 'tt0096895',
#   'Type': 'movie',
#   'DVD': '25 Mar 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Blade Runner',
#   'Year': '1982',
#   'Rated': 'R',
#   'Released': '25 Jun 1982',
#   'Runtime': '117 min',
#   'Genre': 'Action, Sci-Fi, Thriller',
#   'Director': 'Ridley Scott',
#   'Writer': 'Hampton Fancher (screenplay), David Webb Peoples (screenplay), Philip K. Dick (novel)',
#   'Actors': 'Harrison Ford, Rutger Hauer, Sean Young, Edward James Olmos',
#   'Plot': 'A blade runner must pursue and terminate four replicants who stole a ship in space, and have returned to Earth to find their creator.',
#   'Language': 'English, German, Cantonese, Japanese, Hungarian, Arabic',
#   'Country': 'USA, Hong Kong, UK',
#   'Awards': 'Nominated for 2 Oscars. Another 11 wins & 16 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzQzMzJhZTEtOWM4NS00MTdhLTg0YjgtMjM4MDRkZjUwZDBlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '89%'},
#    {'Source': 'Metacritic', 'Value': '89/100'}],
#   'Metascore': '89',
#   'imdbRating': '8.1',
#   'imdbVotes': '646,715',
#   'imdbID': 'tt0083658',
#   'Type': 'movie',
#   'DVD': '27 Aug 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Crash',
#   'Year': '2004',
#   'Rated': 'R',
#   'Released': '06 May 2005',
#   'Runtime': '112 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'Director': 'Paul Haggis',
#   'Writer': 'Paul Haggis (story), Paul Haggis (screenplay), Bobby Moresco (screenplay)',
#   'Actors': 'Karina Arroyave, Dato Bakhtadze, Sandra Bullock, Don Cheadle',
#   'Plot': 'Los Angeles citizens with vastly separate lives collide in interweaving stories of race, loss and redemption.',
#   'Language': 'English, Persian, Spanish, Mandarin, Korean',
#   'Country': 'USA, Germany',
#   'Awards': 'Won 3 Oscars. Another 64 wins & 111 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTk1OTA1MjIyNV5BMl5BanBnXkFtZTcwODQxMTkyMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '69/100'}],
#   'Metascore': '69',
#   'imdbRating': '7.8',
#   'imdbVotes': '405,534',
#   'imdbID': 'tt0375679',
#   'Type': 'movie',
#   'DVD': '06 Sep 2005',
#   'BoxOffice': '$55,382,847',
#   'Production': 'Lions Gate Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'BlacKkKlansman',
#   'Year': '2018',
#   'Rated': 'R',
#   'Released': '10 Aug 2018',
#   'Runtime': '135 min',
#   'Genre': 'Biography, Crime, Drama',
#   'Director': 'Spike Lee',
#   'Writer': 'Charlie Wachtel, David Rabinowitz, Kevin Willmott, Spike Lee, Ron Stallworth (based on the book by)',
#   'Actors': 'Alec Baldwin, John David Washington, Isiah Whitlock Jr., Robert John Burke',
#   'Plot': 'Ron Stallworth, an African American police officer from Colorado Springs, CO, successfully manages to infiltrate the local Ku Klux Klan branch with the help of a Jewish surrogate who eventually becomes its leader. Based on actual events.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 42 wins & 192 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjUyOTE1NjI0OF5BMl5BanBnXkFtZTgwMTM4ODQ5NTM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '83/100'}],
#   'Metascore': '83',
#   'imdbRating': '7.5',
#   'imdbVotes': '170,877',
#   'imdbID': 'tt7349662',
#   'Type': 'movie',
#   'DVD': '06 Nov 2018',
#   'BoxOffice': 'N/A',
#   'Production': 'Focus Features',
#   'Website': 'N/A',
#   'Response': 'True'}]

# %%
 df1 = pd.DataFrame(movie_jsons)

# %%
pd.set_option('display.max_columns', 999)

# %%
df1
# Out:
#                                               Actors  \
# 0  Tom Skerritt, Sigourney Weaver, Veronica Cartw...
# 1  Michael Keaton, Jack Nicholson, Kim Basinger, ...
# 2  Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 3  Karina Arroyave, Dato Bakhtadze, Sandra Bulloc...
# 4  Alec Baldwin, John David Washington, Isiah Whi...
#
#                                               Awards    BoxOffice  \
# 0     Won 1 Oscar. Another 16 wins & 19 nominations.          N/A
# 1      Won 1 Oscar. Another 8 wins & 26 nominations.          N/A
# 2  Nominated for 2 Oscars. Another 11 wins & 16 n...          N/A
# 3   Won 3 Oscars. Another 64 wins & 111 nominations.  $55,382,847
# 4    Won 1 Oscar. Another 42 wins & 192 nominations.          N/A
#
#               Country          DVD      Director                     Genre  \
# 0             UK, USA  06 Jan 2004  Ridley Scott            Horror, Sci-Fi
# 1             USA, UK  25 Mar 1997    Tim Burton         Action, Adventure
# 2  USA, Hong Kong, UK  27 Aug 1997  Ridley Scott  Action, Sci-Fi, Thriller
# 3        USA, Germany  06 Sep 2005   Paul Haggis    Crime, Drama, Thriller
# 4                 USA  06 Nov 2018     Spike Lee   Biography, Crime, Drama
#
#                                             Language Metascore  \
# 0                                            English        89
# 1                           English, French, Spanish        69
# 2  English, German, Cantonese, Japanese, Hungaria...        89
# 3        English, Persian, Spanish, Mandarin, Korean        69
# 4                                            English        83
#
#                                                 Plot  \
# 0  After a space merchant vessel perceives an unk...
# 1  The Dark Knight of Gotham City begins his war ...
# 2  A blade runner must pursue and terminate four ...
# 3  Los Angeles citizens with vastly separate live...
# 4  Ron Stallworth, an African American police off...
#
#                                               Poster             Production  \
# 0  https://m.media-amazon.com/images/M/MV5BMmQ2Mm...       20th Century Fox
# 1  https://m.media-amazon.com/images/M/MV5BMTYwNj...  Warner Bros. Pictures
# 2  https://m.media-amazon.com/images/M/MV5BNzQzMz...  Warner Bros. Pictures
# 3  https://m.media-amazon.com/images/M/MV5BOTk1OT...       Lions Gate Films
# 4  https://m.media-amazon.com/images/M/MV5BMjUyOT...         Focus Features
#
#    Rated                                            Ratings     Released  \
# 0      R  [{'Source': 'Internet Movie Database', 'Value'...  22 Jun 1979
# 1  PG-13  [{'Source': 'Internet Movie Database', 'Value'...  23 Jun 1989
# 2      R  [{'Source': 'Internet Movie Database', 'Value'...  25 Jun 1982
# 3      R  [{'Source': 'Internet Movie Database', 'Value'...  06 May 2005
# 4      R  [{'Source': 'Internet Movie Database', 'Value'...  10 Aug 2018
#
#   Response  Runtime           Title   Type Website  \
# 0     True  117 min           Alien  movie     N/A
# 1     True  126 min          Batman  movie     N/A
# 2     True  117 min    Blade Runner  movie     N/A
# 3     True  112 min           Crash  movie     N/A
# 4     True  135 min  BlacKkKlansman  movie     N/A
#
#                                               Writer  Year     imdbID  \
# 0  Dan O'Bannon (screenplay by), Dan O'Bannon (st...  1979  tt0078748
# 1  Bob Kane (Batman characters), Sam Hamm (story)...  1989  tt0096895
# 2  Hampton Fancher (screenplay), David Webb Peopl...  1982  tt0083658
# 3  Paul Haggis (story), Paul Haggis (screenplay),...  2004  tt0375679
# 4  Charlie Wachtel, David Rabinowitz, Kevin Willm...  2018  tt7349662
#
#   imdbRating imdbVotes
# 0        8.4   734,400
# 1        7.5   321,168
# 2        8.1   646,715
# 3        7.8   405,534
# 4        7.5   170,877

# %%
ratings_list = []

for data in df1["Ratings"]:
    for i in data:
        ratings_list.append(i)

# %%
ratings_list
# Out:
# [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#  {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#  {'Source': 'Metacritic', 'Value': '89/100'},
#  {'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#  {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#  {'Source': 'Metacritic', 'Value': '69/100'},
#  {'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#  {'Source': 'Rotten Tomatoes', 'Value': '89%'},
#  {'Source': 'Metacritic', 'Value': '89/100'},
#  {'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#  {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#  {'Source': 'Metacritic', 'Value': '69/100'},
#  {'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#  {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#  {'Source': 'Metacritic', 'Value': '83/100'}]

# %%
ratings_list[0]
# Out:
# {'Source': 'Internet Movie Database', 'Value': '8.4/10'}

# %%
imdb = []
r_t = []
metacritic = []
for d in ratings_list:
    if d["Source"] == "Internet Movie Database":
        imdb.append(d["Value"])
    elif d["Source"] == "Rotten Tomatoes":
        r_t.append(d["Value"])
    else:
        metacritic.append(d["Value"])

# %%
metacritic
# Out:
# ['89/100', '69/100', '89/100', '69/100', '83/100']

# %%
imdb = [float(x.split("/")[0]) for x in imdb]
r_t = [int(x.rstrip("%")) for x in r_t]
metacritic = [int(x.split("/")[0]) for x in metacritic]

# %%
print(imdb)
print(r_t)
print(metacritic)
# Out:
# [8.4, 7.5, 8.1, 7.8, 7.5]
# [97, 72, 89, 74, 96]
# [89, 69, 89, 69, 83]

# %%
df1["IMDB"] = imdb
df1["Rotten Tomatoes"] = r_t
df1["Metacritic"] = metacritic

# %%
df1["Ratings"]
# Out:
# 0    [{'Source': 'Internet Movie Database', 'Value'...
# 1    [{'Source': 'Internet Movie Database', 'Value'...
# 2    [{'Source': 'Internet Movie Database', 'Value'...
# 3    [{'Source': 'Internet Movie Database', 'Value'...
# 4    [{'Source': 'Internet Movie Database', 'Value'...
# Name: Ratings, dtype: object

# %%
df1
# Out:
#                                               Actors  \
# 0  Tom Skerritt, Sigourney Weaver, Veronica Cartw...
# 1  Michael Keaton, Jack Nicholson, Kim Basinger, ...
# 2  Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 3  Karina Arroyave, Dato Bakhtadze, Sandra Bulloc...
# 4  Alec Baldwin, John David Washington, Isiah Whi...
#
#                                               Awards    BoxOffice  \
# 0     Won 1 Oscar. Another 16 wins & 19 nominations.          N/A
# 1      Won 1 Oscar. Another 8 wins & 26 nominations.          N/A
# 2  Nominated for 2 Oscars. Another 11 wins & 16 n...          N/A
# 3   Won 3 Oscars. Another 64 wins & 111 nominations.  $55,382,847
# 4    Won 1 Oscar. Another 42 wins & 192 nominations.          N/A
#
#               Country          DVD      Director                     Genre  \
# 0             UK, USA  06 Jan 2004  Ridley Scott            Horror, Sci-Fi
# 1             USA, UK  25 Mar 1997    Tim Burton         Action, Adventure
# 2  USA, Hong Kong, UK  27 Aug 1997  Ridley Scott  Action, Sci-Fi, Thriller
# 3        USA, Germany  06 Sep 2005   Paul Haggis    Crime, Drama, Thriller
# 4                 USA  06 Nov 2018     Spike Lee   Biography, Crime, Drama
#
#                                             Language Metascore  \
# 0                                            English        89
# 1                           English, French, Spanish        69
# 2  English, German, Cantonese, Japanese, Hungaria...        89
# 3        English, Persian, Spanish, Mandarin, Korean        69
# 4                                            English        83
#
#                                                 Plot  \
# 0  After a space merchant vessel perceives an unk...
# 1  The Dark Knight of Gotham City begins his war ...
# 2  A blade runner must pursue and terminate four ...
# 3  Los Angeles citizens with vastly separate live...
# 4  Ron Stallworth, an African American police off...
#
#                                               Poster             Production  \
# 0  https://m.media-amazon.com/images/M/MV5BMmQ2Mm...       20th Century Fox
# 1  https://m.media-amazon.com/images/M/MV5BMTYwNj...  Warner Bros. Pictures
# 2  https://m.media-amazon.com/images/M/MV5BNzQzMz...  Warner Bros. Pictures
# 3  https://m.media-amazon.com/images/M/MV5BOTk1OT...       Lions Gate Films
# 4  https://m.media-amazon.com/images/M/MV5BMjUyOT...         Focus Features
#
#    Rated                                            Ratings     Released  \
# 0      R  [{'Source': 'Internet Movie Database', 'Value'...  22 Jun 1979
# 1  PG-13  [{'Source': 'Internet Movie Database', 'Value'...  23 Jun 1989
# 2      R  [{'Source': 'Internet Movie Database', 'Value'...  25 Jun 1982
# 3      R  [{'Source': 'Internet Movie Database', 'Value'...  06 May 2005
# 4      R  [{'Source': 'Internet Movie Database', 'Value'...  10 Aug 2018
#
#   Response  Runtime           Title   Type Website  \
# 0     True  117 min           Alien  movie     N/A
# 1     True  126 min          Batman  movie     N/A
# 2     True  117 min    Blade Runner  movie     N/A
# 3     True  112 min           Crash  movie     N/A
# 4     True  135 min  BlacKkKlansman  movie     N/A
#
#                                               Writer  Year     imdbID  \
# 0  Dan O'Bannon (screenplay by), Dan O'Bannon (st...  1979  tt0078748
# 1  Bob Kane (Batman characters), Sam Hamm (story)...  1989  tt0096895
# 2  Hampton Fancher (screenplay), David Webb Peopl...  1982  tt0083658
# 3  Paul Haggis (story), Paul Haggis (screenplay),...  2004  tt0375679
# 4  Charlie Wachtel, David Rabinowitz, Kevin Willm...  2018  tt7349662
#
#   imdbRating imdbVotes  IMDB  Rotten Tomatoes  Metacritic
# 0        8.4   734,400   8.4               97          89
# 1        7.5   321,168   7.5               72          69
# 2        8.1   646,715   8.1               89          89
# 3        7.8   405,534   7.8               74          69
# 4        7.5   170,877   7.5               96          83

# %%
df1 = df1.drop(["Country", "DVD", "Language", "Metascore", "Ratings", "Response", "imdbRating"], axis = 1)

# %%
string = df1["Awards"][0]
oscars = re.search(r'Won (\d+)', string).group(1)
oscars
# Out:
# '1'

# %%
more_wins = re.search(r'(\d+) win', string)
if more_wins:
    print(more_wins.group(1))
else:
    print("No more wins")
more_noms = re.search(r'(\d+) nominations', string)
if more_noms:
    print(more_noms.group(1))
    print(type(more_noms.group(1)))
    print(int(more_noms.group(1)))
else:
    print("No more noms")
big_noms = re.search(r'Nominated for (\d+)', string)
if big_noms:
    print(big_noms.group(1))
    print(type(big_noms.group(1)))
else:
    print("No big noms")
big_wins = re.search(r'Won (\d+)', string)
if big_wins:
    print(big_wins.group(1))
else:
    print("No big wins")
# Out:
# 16
# 19
# <class 'str'>
# 19
# No big noms
# 1

# %%
string
# Out:
# 'Won 1 Oscar. Another 16 wins & 19 nominations.'

# %%
wins_list = []
noms_list = []

for x in df1["Awards"]:
    wins = 0
    noms = 0
    big_wins = re.search(r'Won (\d+)', x)
    if big_wins:
        wins += int(big_wins.group(1))
    big_noms = re.search(r'Nominated for (\d+)', x)
    if big_noms:
        noms += int(big_noms.group(1))
    more_wins = re.search(r'(\d+) win', x)
    if more_wins:
        wins += int(more_wins.group(1))
    more_noms = re.search(r'(\d+) nominations', x)
    if more_noms:
        noms += int(more_noms.group(1))
    wins_list.append(wins)
    noms_list.append(noms)
    
print(wins_list)
print(noms_list)
# Out:
# [17, 9, 11, 67, 43]
# [19, 26, 18, 111, 192]

# %%
df1["Wins"] = wins_list
df1["Nominations"] = noms_list

# %%
df1
# Out:
#                                               Actors  \
# 0  Tom Skerritt, Sigourney Weaver, Veronica Cartw...
# 1  Michael Keaton, Jack Nicholson, Kim Basinger, ...
# 2  Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 3  Karina Arroyave, Dato Bakhtadze, Sandra Bulloc...
# 4  Alec Baldwin, John David Washington, Isiah Whi...
#
#                                               Awards    BoxOffice  \
# 0     Won 1 Oscar. Another 16 wins & 19 nominations.          N/A
# 1      Won 1 Oscar. Another 8 wins & 26 nominations.          N/A
# 2  Nominated for 2 Oscars. Another 11 wins & 16 n...          N/A
# 3   Won 3 Oscars. Another 64 wins & 111 nominations.  $55,382,847
# 4    Won 1 Oscar. Another 42 wins & 192 nominations.          N/A
#
#        Director                     Genre  \
# 0  Ridley Scott            Horror, Sci-Fi
# 1    Tim Burton         Action, Adventure
# 2  Ridley Scott  Action, Sci-Fi, Thriller
# 3   Paul Haggis    Crime, Drama, Thriller
# 4     Spike Lee   Biography, Crime, Drama
#
#                                                 Plot  \
# 0  After a space merchant vessel perceives an unk...
# 1  The Dark Knight of Gotham City begins his war ...
# 2  A blade runner must pursue and terminate four ...
# 3  Los Angeles citizens with vastly separate live...
# 4  Ron Stallworth, an African American police off...
#
#                                               Poster             Production  \
# 0  https://m.media-amazon.com/images/M/MV5BMmQ2Mm...       20th Century Fox
# 1  https://m.media-amazon.com/images/M/MV5BMTYwNj...  Warner Bros. Pictures
# 2  https://m.media-amazon.com/images/M/MV5BNzQzMz...  Warner Bros. Pictures
# 3  https://m.media-amazon.com/images/M/MV5BOTk1OT...       Lions Gate Films
# 4  https://m.media-amazon.com/images/M/MV5BMjUyOT...         Focus Features
#
#    Rated     Released  Runtime           Title   Type Website  \
# 0      R  22 Jun 1979  117 min           Alien  movie     N/A
# 1  PG-13  23 Jun 1989  126 min          Batman  movie     N/A
# 2      R  25 Jun 1982  117 min    Blade Runner  movie     N/A
# 3      R  06 May 2005  112 min           Crash  movie     N/A
# 4      R  10 Aug 2018  135 min  BlacKkKlansman  movie     N/A
#
#                                               Writer  Year     imdbID  \
# 0  Dan O'Bannon (screenplay by), Dan O'Bannon (st...  1979  tt0078748
# 1  Bob Kane (Batman characters), Sam Hamm (story)...  1989  tt0096895
# 2  Hampton Fancher (screenplay), David Webb Peopl...  1982  tt0083658
# 3  Paul Haggis (story), Paul Haggis (screenplay),...  2004  tt0375679
# 4  Charlie Wachtel, David Rabinowitz, Kevin Willm...  2018  tt7349662
#
#   imdbVotes  IMDB  Rotten Tomatoes  Metacritic  Wins  Nominations
# 0   734,400   8.4               97          89    17           19
# 1   321,168   7.5               72          69     9           26
# 2   646,715   8.1               89          89    11           18
# 3   405,534   7.8               74          69    67          111
# 4   170,877   7.5               96          83    43          192
