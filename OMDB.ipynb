# %%
import requests
import json
import pandas as pd
import numpy as np
from config2 import omdb_key, tmdb_key, pwrd
import warnings
from pprint import pprint
import re
import time
from sqlalchemy import create_engine
warnings.filterwarnings('ignore')

# %%
#create url list for API calls to The Movie Database for the first 500 pages of movies
url_list = []


for i in range(1,501):
    num = i
    url = "https://api.themoviedb.org/3/discover/movie?api_key="+tmdb_key+"&language=en-US&&sort_by=vote_count.desc&include_adult=false&include_video=false&page=" + str(num)
    url_list.append(url)

# %%
len(url_list)

# %%
#loop through url's and make API call for each

movies_list = []

for i in url_list:
    r = requests.get(i)
    print(r)
    r = r.json()
    movies_list.append(r["results"])

# %%
len(movies_list)

# %%
#get movies from each page into a list (there are 20 moives per page)
m_list = []

for i in range(len(movies_list)):
    for j in range(20):
        m_list.append(movies_list[i][j].items())

# %%
print(f"There are {len(m_list)} movies in the database")

# %%
#put movies in data frame
mymovies_df = pd.DataFrame(m_list)
mymovies_df.head()

# %%
#rename columns
mymovies_df.columns = ["popularity", "tmdb_vote_count", "video", "poster_path", "id", "adult", "backdrop_path", "original_language", "original_title", "genre_ids", "title", "vote_average", "overview", "release_date"]

# %%
print(mymovies_df.columns)

# %%
#create smaller df with the columns we want
short_df = mymovies_df[['original_title','overview']].copy()
short_df.head()

# %%
#remove tuple from each cell and only show data
for x in short_df.columns:
    short_df[x] = [y[1] for y in short_df[x]]

# %%
short_df.head()

# %%
#create list for json results and url variables for API call
movie_jsons = []
url1 = "http://www.omdbapi.com/?t="
url2 = "&apikey="

# %%
#loop through movies and make API call for each title
for movie in short_df["original_title"]:
    url = url1 + movie + url2 + omdb_key
    response = requests.get(url)
    print(response)
    response = response.json()
    movie_jsons.append(response)
    time.sleep(.2)

# %%
 #create dataframe
df1 = pd.DataFrame(movie_jsons)

# %%
#set max column view and check dataframe
pd.set_option('display.max_columns', 999)
df1.head()

# %%
#check data count
df1.count()

# %%
#drop rows that have no ratings
df1 = df1[pd.notnull(df1['Ratings'])]

# %%
#drop rows that have no Box Office
df1 = df1[pd.notnull(df1['BoxOffice'])]

# %%
df1.count()

# %%
total_ratings = [len(data) for data in df1["Ratings"]]

# %%
total_ratings.count(3)

# %%
#remove movies that dont have ratings from all 3 sources
df1 = df1[df1["Ratings"].map(len)==3]

# %%
df1.count()

# %%
#create list of all ratings in the dataframe
ratings_list = []
for data in df1["Ratings"]:
    for i in data:
        ratings_list.append(i)
ratings_list[:5]

# %%
#create spearate list for each source
imdb = []
r_t = []
metacritic = []
for d in ratings_list:
    if d["Source"] == "Internet Movie Database":
        imdb.append(d["Value"])
    elif d["Source"] == "Rotten Tomatoes":
        r_t.append(d["Value"])
    else:
        metacritic.append(d["Value"])

# %%
#check sample list
print(len(imdb))
print(len(r_t))
print(len(metacritic))

# %%
#convert strings to floats and ints
imdb = [float(x.split("/")[0]) for x in imdb]
r_t = [int(x.rstrip("%")) for x in r_t]
metacritic = [int(x.split("/")[0]) for x in metacritic]

# %%
#check results
print(imdb[:5])
print(r_t[:5])
print(metacritic[:5])

# %%
print(len(imdb))
print(len(r_t))
print(len(metacritic))

# %%
#create new columns
df1["IMDB"] = imdb
df1["Rotten Tomatoes"] = r_t
df1["Metacritic"] = metacritic

# %%
#check dataframe 
df1

# %%
#drop unwanted columns
df1 = df1.drop(["Country", "DVD", "Error", "Language", "Metascore", "Ratings", "Response", "imdbRating", "Website"], axis = 1)

# %%
#create variable for regex test
string = df1["Awards"][0]

# %%
#test regex code
more_wins = re.search(r'(\d+) win', string)
if more_wins:
    print(more_wins.group(1))
else:
    print("No more wins")
more_noms = re.search(r'(\d+) nominations', string)
if more_noms:
    print(more_noms.group(1))
    print(type(more_noms.group(1)))
    print(int(more_noms.group(1)))
else:
    print("No more noms")
big_noms = re.search(r'Nominated for (\d+)', string)
if big_noms:
    print(big_noms.group(1))
    print(type(big_noms.group(1)))
else:
    print("No big noms")
big_wins = re.search(r'Won (\d+)', string)
if big_wins:
    print(big_wins.group(1))
else:
    print("No big wins")

# %%
#create wins and noms list. Prase through 

wins_list = []
noms_list = []

for x in df1["Awards"]:
    wins = 0
    noms = 0
    big_wins = re.search(r'Won (\d+)', x)
    if big_wins:
        wins += int(big_wins.group(1))
    big_noms = re.search(r'Nominated for (\d+)', x)
    if big_noms:
        noms += int(big_noms.group(1))
    more_wins = re.search(r'(\d+) win', x)
    if more_wins:
        wins += int(more_wins.group(1))
    more_noms = re.search(r'(\d+) nominations', x)
    if more_noms:
        noms += int(more_noms.group(1))
    wins_list.append(wins)
    noms_list.append(noms)
    
print(wins_list[:5])
print(noms_list[:5])

# %%
#adds wins and nominations to df1
df1["Wins"] = wins_list
df1["Nominations"] = noms_list

# %%
#convert runtime to int
df1["Runtime"] = [int(x.split(" ")[0]) for x in df1["Runtime"]]

# %%
#drop rows that has no imdbVotes
df1 = df1[~df1["imdbVotes"].str.contains("N/A")]

# %%
df1.count()

# %%
#convert imdbVotes to string
df1["imdbVotes"] = [int(x.replace(',','')) for x in df1["imdbVotes"]]

# %%
#check dataframe
df1.head()

# %%
#save as csv
df1.to_csv("data/movies.csv")

# %%
#reload csv for SQL Load
df1 = pd.read_csv("data/movies.csv")

# %%
print(df1.columns)
# Out:
# Index(['Unnamed: 0', 'Actors', 'Awards', 'BoxOffice', 'Director', 'Genre',
#        'Plot', 'Poster', 'Production', 'Rated', 'Released', 'Runtime', 'Title',
#        'Type', 'Writer', 'Year', 'imdbID', 'imdbVotes', 'totalSeasons', 'IMDB',
#        'Rotten Tomatoes', 'Metacritic', 'Wins', 'Nominations'],
#       dtype='object')

# %%
#drop Unnamed column
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %%
#rename Rotten Tomatoes column
df1.rename(columns = {'Rotten Tomatoes':'Rotten_Tomatoes'}, inplace = True)

# %%
#connect to local database
rds_connection_string = "postgres:"+ pwrd + "@localhost:5432/movie_finder"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#export movie data to SQL
df1.to_sql(name='movies', con=engine, if_exists='replace', index=True)

# %%
#check tables
engine.table_names()
# Out:
# ['movies']

# %%
#add primary key
engine.execute('alter table movies add primary key(index)')

# %%
#read tables from SQL
pd.read_sql("SELECT * FROM movies",con=engine)
# Out:
#       index  Unnamed: 0                                             Actors  \
# 0         0           0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 1         1           1  Ryan Reynolds, Karan Soni, Ed Skrein, Michael ...
# 2         2           2  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 3         3           3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4         4           4  Ellen Burstyn, Matthew McConaughey, Mackenzie ...
# 5         5           5  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 6         6           6  Chris Pratt, Zoe Saldana, Dave Bautista, Vin D...
# 7         7           7  Edward Norton, Brad Pitt, Meat Loaf, Zach Grenier
# 8         8           8  Robert Downey Jr., Terrence Howard, Jeff Bridg...
# 9         9           9  Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
# 10       10          10  Tim Roth, Amanda Plummer, Laura Lovelace, John...
# 11       11          11  Tom Hanks, Rebecca Williams, Sally Field, Mich...
# 12       12          12  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 13       13          13  Alan Howard, Noel Appleby, Sean Astin, Sala Baker
# 14       14          14  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 15       15          15  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...
# 16       16          16  Stanley Tucci, Wes Bentley, Jennifer Lawrence,...
# 17       17          17  Tom Hardy, Charlize Theron, Nicholas Hoult, Hu...
# 18       18          19  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...
# 19       19          20  Chris Evans, Robert Downey Jr., Scarlett Johan...
# 20       20          21  Christian Bale, Gary Oldman, Tom Hardy, Joseph...
# 21       21          22  Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...
# 22       22          23  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 23       23          24  Will Smith, Jaime FitzSimons, Ike Barinholtz, ...
# 24       24          25  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 25       25          26   Noel Appleby, Ali Astin, Sean Astin, David Aston
# 26       26          27  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 27       27          28  Chris Evans, Hayley Atwell, Sebastian Stan, To...
# 28       28          29  Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 29       29          30  Chris Hemsworth, Natalie Portman, Tom Hiddlest...
# ...     ...         ...                                                ...
# 4869   4869        5526  Kate Beckinsale, Jim Sturgess, David Thewlis, ...
# 4870   4870        5527  Jamie Lee Curtis, Adam Arkin, Michelle William...
# 4871   4871        5528  David Rawle, Brendan Gleeson, Lisa Hannigan, F...
# 4872   4872        5529  Eddie Murphy, Kerry Washington, Emanuel Ragsda...
# 4873   4873        5530  Steve Carell, Maura Tierney, Jack Dylan Grazer...
# 4874   4874        5532  Jean-Claude Van Damme, Donald Gibb, Leah Ayres...
# 4875   4875        5533  Mel Gibson, Julia Roberts, Patrick Stewart, Cy...
# 4876   4876        5534  Meryl Streep, Steve Martin, Alec Baldwin, John...
# 4877   4877        5535  Nicole Kidman, Daniel Craig, Jeremy Northam, J...
# 4878   4878        5536  Douglas Smith, Lucien Laviscount, Cressida Bon...
# 4879   4879        5539  Nicole Kidman, Sean Penn, Catherine Keener, Je...
# 23       Won 1 Oscar. Another 16 wins & 37 nominations.  $325,021,779
# 24    Nominated for 7 Oscars. Another 19 wins & 32 n...          None
# 25    Won 11 Oscars. Another 198 wins & 122 nominati...  $364,000,000
# 26                             9 wins & 62 nominations.  $125,001,000
# 27                             3 wins & 46 nominations.  $176,636,816
# 28    Won 3 Oscars. Another 101 wins & 246 nominations.  $501,105,037
# 29                             5 wins & 30 nominations.  $181,015,141
# ...                                                 ...           ...
# 4869                              1 win & 1 nomination.          None
# 4870                            1 win & 11 nominations.          None
# 4871  Nominated for 1 Oscar. Another 11 wins & 24 no...          None
# 4872                                     3 nominations.   $18,429,081
# 4873  Nominated for 1 Golden Globe. Another 8 wins &...          None
# 4874                                      1 nomination.          None
# 4875                             4 wins & 1 nomination.          None
# 4876  Nominated for 3 Golden Globes. Another 8 wins ...  $112,703,470
# 4877                             1 win & 2 nominations.   $15,100,000
# 4878                                               None   $22,377,458
# 4879                            3 wins & 2 nominations.   $72,515,360
# 4880                             1 win & 2 nominations.      $125,475
# 4881                                               None          None
# 4882                            2 wins & 5 nominations.          None
# 4883                                     3 nominations.   $35,096,190
# 4884  Nominated for 1 Golden Globe. Another 5 wins &...          None
# 4885                            1 win & 10 nominations.   $38,509,342
# 4886                                      1 nomination.   $19,478,384
# 4887                                      1 nomination.   $20,757,977
# 4888                          10 wins & 10 nominations.   $42,219,433
# 4889                                     9 nominations.   $31,487,293
# 4890                             1 win & 4 nominations.   $43,056,895
# 4891  Nominated for 1 Oscar. Another 28 wins & 55 no...    $4,694,484
# 4892     Won 1 Oscar. Another 50 wins & 44 nominations.    $7,851,076
# 4893    Won 6 Oscars. Another 17 wins & 18 nominations.          None
# 4894                            1 win & 10 nominations.          None
# 4895                                             1 win.   $32,153,522
# 4896                          35 wins & 70 nominations.          None
# 4897                           9 wins & 20 nominations.    $1,800,000
# 4898    Won 9 Oscars. Another 49 wins & 18 nominations.          None
#
#                                  Director  \
# 0                       Christopher Nolan
# 1                              Tim Miller
# 2                             Joss Whedon
# 3                       Christopher Nolan
# 4                       Christopher Nolan
# 5                           James Cameron
# 6                              James Gunn
# 7                           David Fincher
# 8                             Jon Favreau
# 9                       Quentin Tarantino
# 10                      Quentin Tarantino
# 11                        Robert Zemeckis
# 12               Anthony Russo, Joe Russo
# 13                          Peter Jackson
# 14        Lana Wachowski, Lilly Wachowski
# 15                          James Cameron
# 16                              Gary Ross
# 17                          George Miller
# 18                            Shane Black
# 19               Anthony Russo, Joe Russo
# 20                      Christopher Nolan
# 21                        Colin Trevorrow
# 22                            Joss Whedon
# 23                             David Ayer
# 24                         Frank Darabont
# 25                          Peter Jackson
# 26                        Martin Scorsese
# 27                           Joe Johnston
# 28                           Ryan Coogler
# 29                        Kenneth Branagh
# ...                                   ...
# 4869                        Brad Anderson
# 4870                          Steve Miner
# 4871                           Tomm Moore
# 4872                        Brian Robbins
# 4873                 Felix van Groeningen
# 4874                          Newt Arnold
# 4875                       Richard Donner
# 4876                         Nancy Meyers
# 4877  Oliver Hirschbiegel, James McTeigue
# 4878                          Stacy Title
# 4879                       Sydney Pollack
# 4880                    Sebastián Cordero
# 4881                       Panos Cosmatos
# 4882                       Frank Marshall
# 4883                Joel Coen, Ethan Coen
# 4884                          Kevin Smith
# 4885                        Adam Shankman
# 4886                      Kevin Macdonald
# 4887                        Baran bo Odar
# 4888                   M. Night Shyamalan
# 4889                        Peter Sollett
# 4890                         Stuart Baird
# 4891                        Terry Zwigoff
# 4892                         Asif Kapadia
# 4893                 Joseph L. Mankiewicz
# 4894                        Peter Jackson
# 4895                          Richie Keen
# 4896                Destin Daniel Cretton
# 4897                     William Friedkin
# 4898                  Bernardo Bertolucci
#
#                                              Genre  \
# 0              Action, Adventure, Sci-Fi, Thriller
# 1                Action, Adventure, Comedy, Sci-Fi
# 2                        Action, Adventure, Sci-Fi
# 3                   Action, Crime, Drama, Thriller
# 4                         Adventure, Drama, Sci-Fi
# 5               Action, Adventure, Fantasy, Sci-Fi
# 6                Action, Adventure, Comedy, Sci-Fi
# 7                                            Drama
# 8                        Action, Adventure, Sci-Fi
# 9                                   Drama, Western
# 10                                    Crime, Drama
# 11                                  Drama, Romance
# 12                       Action, Adventure, Sci-Fi
# 13                       Adventure, Drama, Fantasy
# 14                                  Action, Sci-Fi
# 15                                  Drama, Romance
# 16             Action, Adventure, Sci-Fi, Thriller
# 17             Action, Adventure, Sci-Fi, Thriller
# 18                       Action, Adventure, Sci-Fi
# 19                       Action, Adventure, Sci-Fi
# 20                                Action, Thriller
# 21                       Action, Adventure, Sci-Fi
# 22                       Action, Adventure, Sci-Fi
# 23              Action, Adventure, Fantasy, Sci-Fi
# 24                                           Drama
# 25                       Adventure, Drama, Fantasy
# 26                               Mystery, Thriller
# 27                       Action, Adventure, Sci-Fi
# 28                       Action, Adventure, Sci-Fi
# 29                      Action, Adventure, Fantasy
# ...                                            ...
# 4869                       Drama, Horror, Thriller
# 4870                              Horror, Thriller
# 4871  Animation, Adventure, Drama, Family, Fantasy
# 4872                                 Comedy, Drama
# 4873                              Biography, Drama
# 4874               Action, Biography, Drama, Sport
# 4875                     Action, Mystery, Thriller
# 4876                        Comedy, Drama, Romance
# 4877                              Sci-Fi, Thriller
# 4878     Drama, Fantasy, Horror, Mystery, Thriller
# 4879                      Crime, Mystery, Thriller
# 4880              Drama, Mystery, Sci-Fi, Thriller
# 4881    Action, Fantasy, Horror, Mystery, Thriller
# 4882             Comedy, Fantasy, Horror, Thriller
# 4883                        Comedy, Crime, Romance
# 4884                        Comedy, Drama, Romance
# 4885               Comedy, Drama, Musical, Romance
# 4886        Action, Adventure, Drama, History, War
# 4887                       Action, Crime, Thriller
# 4888             Drama, Fantasy, Mystery, Thriller
# 4889                 Comedy, Drama, Music, Romance
# 4890           Action, Adventure, Sci-Fi, Thriller
# 4891                                 Comedy, Drama
# 4892                 Documentary, Biography, Music
# 4893                                         Drama
# 4894                       Comedy, Fantasy, Horror
# 4895                                        Comedy
# 4896                                         Drama
# 4897                        Crime, Drama, Thriller
# 4898                     Biography, Drama, History
#
#                                                    Plot  \
# 0     A thief who steals corporate secrets through t...
# 1     A wisecracking mercenary gets experimented on ...
# 4895  https://m.media-amazon.com/images/M/MV5BMTg0Nz...
# 4896  https://m.media-amazon.com/images/M/MV5BMTEwNj...
# 4897  https://m.media-amazon.com/images/M/MV5BN2JhZD...
# 4898  https://m.media-amazon.com/images/M/MV5BZTk0ND...
#
#                            Production  ...  \
# 0               Warner Bros. Pictures  ...
# 1                    20th Century Fox  ...
# 2                Walt Disney Pictures  ...
# 3     Warner Bros. Pictures/Legendary  ...
# 4                  Paramount Pictures  ...
# 5                    20th Century Fox  ...
# 6                Walt Disney Pictures  ...
# 7                    20th Century Fox  ...
# 8                  Paramount Pictures  ...
# 9                   The Weinstein Co.  ...
# 10                      Miramax Films  ...
# 11                 Paramount Pictures  ...
# 12               Walt Disney Pictures  ...
# 13                    New Line Cinema  ...
# 14              Warner Bros. Pictures  ...
# 15                 Paramount Pictures  ...
# 16                          Lionsgate  ...
# 17                       Warner Bros.  ...
# 18               Walt Disney Pictures  ...
# 19               Walt Disney Pictures  ...
# 20              Warner Bros. Pictures  ...
# 21                 Universal Pictures  ...
# 22               Walt Disney Pictures  ...
# 23              Warner Bros. Pictures  ...
# 24                  Columbia Pictures  ...
# 25                    New Line Cinema  ...
# 26                  Paramount Studios  ...
# 27                 Paramount Pictures  ...
# 28                     Marvel Studios  ...
# 29                 Paramount Pictures  ...
# ...                               ...  ...
# 4869          Millenium Entertainment  ...
# 4870                          Miramax  ...
# 4871                            GKIDS  ...
# 4872               Paramount Pictures  ...
# 4873                   Amazon Studios  ...
# 4874                Warner Home Video  ...
# 4875                Warner Home Video  ...
# 4876               Universal Pictures  ...
# 4877           Warners Bros. Pictures  ...
# 4878                STX Entertainment  ...
# 4879               Universal Pictures  ...
# 4880                Magnolia Pictures  ...
# 4881                       RLJE Films  ...
# 4882             Buena Vista Pictures  ...
# 4883               Universal Pictures  ...
# 4884                    Miramax Films  ...
# 4885                  New Line Cinema  ...
# 4886                   Focus Features  ...
# 4887                  Open Road Films  ...
# 4888            Warner Bros. Pictures  ...
# 4889        Sony Pictures/Screen Gems  ...
# 4890               Paramount Pictures  ...
# 4891                   United Artists  ...
# 4892                        A24 Films  ...
# 4893                 20th Century Fox  ...
# 4894                        Universal  ...
# 4895            Warner Bros. Pictures  ...
# 4896                         Cinedigm  ...
# 4897             Independent Pictures  ...
# 4898                Columbia Pictures  ...
#
#                                                  Writer  Year     imdbID  \
# 0                                     Christopher Nolan  2010  tt1375666
# 1                             Rhett Reese, Paul Wernick  2016  tt1431045
# 2     Joss Whedon (screenplay), Zak Penn (story), Jo...  2012  tt0848228
# 3     Jonathan Nolan (screenplay), Christopher Nolan...  2008  tt0468569
# 4                     Jonathan Nolan, Christopher Nolan  2014  tt0816692
# 5                                         James Cameron  2009  tt0499549
# 6     James Gunn, Nicole Perlman, Dan Abnett (based ...  2014  tt2015381
# 7        Chuck Palahniuk (novel), Jim Uhls (screenplay)  1999  tt0137523
# 8     Mark Fergus (screenplay), Hawk Ostby (screenpl...  2008  tt0371746
# 9                                     Quentin Tarantino  2012  tt1853728
# 10    Quentin Tarantino (stories), Roger Avary (stor...  1994  tt0110912
