# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from pprint import pprint
from config import ODMb_api_key
import json
key="342919475fdd9494b35f7a36b0bae916"

# %%
url_list = []

for i in range(500):
    num = i
    url = "https://api.themoviedb.org/3/movie/popular?api_key="+key+"&language=en-US&page=" + str(num)
    url_list.append(url)

    
print(url_list)
    
    

# "https://api.themoviedb.org/3/movie/?api_key="

# https://api.themoviedb.org/3/movie/popular?api_key=ODMb_api_key&language=en-US&page=1
# Out:
# ['https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=0', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=1', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=2', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=3', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=4', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=5', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=6', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=7', 'https://api.themoviedb.org/3/movie/popular?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=8', 'https://api.the
# ...

# %%
print(key)
# Out:
# 342919475fdd9494b35f7a36b0bae916

# %%
# response2 = requests.get(url1+crime+url2+fbi_key, params={'page:2'})

# %%
movies = requests.get(url).json()

# %%
# movies

# %%
# for i in range(500):
#     num = i
#     print(i)

# %%
def query_api(url_list):
    r = requests.get(url)
    info = r.json()
    return info['total_results'], info['results']

n, r = query_api(url_list)

movie_list =[]
while n:
    for i in r:
        movie_list.append(i)
#         print(i['original_title'])
#         movie_list.append(i)
    
        
    n, r = query_api(n)

#print(movie_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-2fde793e0024> in <module>
#      14
#      15
# ---> 16     n, r = query_api(n)
#      17
#      18 #print(movie_list)
#
# <ipython-input-34-2fde793e0024> in query_api(url_list)
#       1 def query_api(url_list):
# ----> 2     r = requests.get(url)
#       3     info = r.json()
#       4     return info['total_results'], info['results']
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...

# %%
moviedata_list = movieslist.items()

# %%
for moviedb in moviedata_list:
    pprint(moviedb)
# Out:
# ('page', 1)
# ('total_results', 10000)
# ('total_pages', 500)
# ('results',
#  [{'adult': False,
#    'backdrop_path': '/5BwqwxMEjeFtdknRV792Svo0K1v.jpg',
#    'genre_ids': [12, 18, 9648, 878, 53],
#    'id': 419704,
#    'original_language': 'en',
#    'original_title': 'Ad Astra',
#    'overview': 'The near future, a time when both hope and hardships drive '
#                'humanity to look to the stars and beyond. While a mysterious '
#                'phenomenon menaces to destroy life on planet Earth, astronaut '
#                'Roy McBride undertakes a mission across the immensity of space '
#                'and its many perils to uncover the truth about a lost '
#                'expedition that decades before boldly faced emptiness and '
#                'silence in search of the unknown.',
#    'popularity': 476.043,
#    'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#    'release_date': '2019-09-17',
#    'title': 'Ad Astra',
#    'video': False,
# ...

# %%
mymovies = pd.DataFrame(moviedb[1])

# %%
mymovies.head(100)
# Out:
#     popularity  vote_count  video                       poster_path      id  \
# 0      476.043        1323  False  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg  419704
# 1      293.642         344  False  /l4iknLOenijaB85Zyb5SxH1gGz8.jpg  512200
# 2      258.317         453  False  /lnWkyG3LLgbbrIEeyl5mK5VRFe4.jpg  509967
# 3      287.655         116  False  /db32LaOibwEliAmSL2jjDF6oDdj.jpg  181812
# 4      183.288        1073  False  /pjeMs3yqRmFL3giJy4PMXWZTTPa.jpg  330457
# 5      271.298        6553  False  /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg  475557
# 6      109.280        8443  False  /jpfkzbIXgKZqCZAkEkFH2VYF63s.jpg     920
# 7      124.369        3282  False  /8j58iEBw9pOXFD2L0nt0ZXeHviB.jpg  466272
# 8       84.264         742  False  /pZekG6xabTmZxjmYw10wN84Hp8d.jpg  492188
# 9      145.272          13  False  /vn94LlNrbUWIZZyAdmvUepFBeaY.jpg  449924
# 10      82.211        1447  False  /mbm8k3GFhXS0ROd9AD1gqYbIFbM.jpg  398978
# ...

# %%
mymovies.count()
# Out:
# popularity           20
# vote_count           20
# video                20
# poster_path          20
# id                   20
# adult                20
# backdrop_path        18
# original_language    20
# original_title       20
# genre_ids            20
# title                20
# vote_average         20
# overview             20
# release_date         20
# dtype: int64
