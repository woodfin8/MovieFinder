919475fdd9494b35f7a36b0bae916&language=en-US&page=25', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=26', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=27', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=28', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=29', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=30', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=31', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=32', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=33', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=34', 'https://api.themoviedb.org/3/movie/popularity?api_key=342919475fdd9494b35f7a36b0bae916&language=en-US&page=35', 'https://api.themoviedb.org/3/movie/popularity?api_ke ...

# %%
print(key)
# Out:
# 342919475fdd9494b35f7a36b0bae916

# %%
def query_api(car):
    r = requests.get(car)
    info = r.json()
    return info['results']


movies_list = []

for i in url_list:
    r = query_api(i)    
    movies_list.append(r)

# %%
m_list = []

for i in range(len(movies_list)):
    for j in range(20):
        m_list.append(movies_list[i][j].items())
        
        #mymovies_df = pd.DataFrame(m_list)
        
        #m_list = m_list.split(',')
        
        print(m_list)

# %%
 mymovies_df = pd.DataFrame(m_list)

# %%
mymovies_df.head(100)

# %%
cols = []
for col in mymovies_df.columns:
    col = str(col)
    cols.append(col.lower())
mymovies_df.columns = cols
cols

# %%
mymovies_df =mymovies_df.rename(columns = {'0': 'popularity', '1': 'vote_count', '2': 'video' , '3': 'poster_path', '4': 'id' , '5': 'adult' , '6': 'backdrop_path' , '7': 'original_language', '8': 'original_title', '9': 'genre_ids' , '10': 'title' , '11': 'vote_average' , '12': 'overview' , '13': 'release_date'})

# %%
mymovies_df

# %%
popularity = []

for i in mymovies_df['popularity']:
    pop1, pop2 = i
    popularity.append(pop2)
    
    pop_col_df = pd.DataFrame(popularity)
        


    pop_col_df = pop_col_df.rename(columns = {0 : "popularity"})

# %%
vote_count = []

for i in mymovies_df['vote_count']:
    pop1, pop2 = i
    vote_count.append(pop2)
    
    vote_count_df= pd.DataFrame(vote_count)
    
    vote_count_df = vote_count_df.rename(columns = {0 : "vote_count"})
    

#vote_count_df

# %%
video = []

for i in mymovies_df['video']:
    pop1, pop2 = i
    video.append(pop2)
    
    video_df = pd.DataFrame(video)
    
    video_df = video_df.rename(columns = {0 : "video"})
    
#video_df

# %%
poster_path = []

for i in mymovies_df['poster_path']:
    pop1, pop2 = i
    poster_path.append(pop2)
    
    poster_path_df = pd.DataFrame(poster_path)
    
    poster_path_df = poster_path_df.rename(columns = {0 : "poster_path"})
    
#poster_path_df

# %%
id = []

for i in mymovies_df['id']:
    pop1, pop2 = i
    id.append(pop2)
    
    id_df = pd.DataFrame(id)
    
    id_df = id_df.rename(columns = {0 : "id"})
    

#id_df

# %%
adult = []

for i in mymovies_df['adult']:
    pop1, pop2 = i
    adult.append(pop2)
    
    adult_df = pd.DataFrame(adult)
    
    adult_df = adult_df.rename(columns = {0 : "adult"})
    
    adult_df.replace(['Joker', 'Star Wars'], False, inplace=True)
    

#adult_df

# %%
backdrop_path = []

for i in mymovies_df['backdrop_path']:
    pop1, pop2 = i
    backdrop_path.append(pop2)
    
    backdrop_path_df = pd.DataFrame(backdrop_path)
    
    backdrop_path_df = backdrop_path_df.rename(columns = {0 : "backdrop_path"})
    

#backdrop_path_df

# %%
original_language = []

for i in mymovies_df['original_language']:
    pop1, pop2 = i
    original_language.append(pop2)
    
    original_language_df = pd.DataFrame(original_language)
    
    original_language_df = original_language_df.rename(columns = {0 : "original_language"})

#original_language_df

# %%
original_title = []

for i in mymovies_df['original_title']:
    pop1, pop2 = i
    original_title.append(pop2)
    
    original_title_df = pd.DataFrame(original_title)
    
    original_title_df = original_title_df.rename(columns = {0 : "original_title"})

#original_title_df

# %%
genre_ids = []

for i in mymovies_df['genre_ids']:
    pop1, pop2 = i
    genre_ids.append(pop2)
    
    genre_ids_df = pd.DataFrame(genre_ids)
    
    genre_ids_df = genre_ids_df.rename(columns = {0 : "genre_ids_df"})
    
    
    

#genre_ids_df

# %%
title = []

for i in mymovies_df['title']:
    pop1, pop2 = i
    title.append(pop2)
    
    title_df = pd.DataFrame(title)
    
    title_df = title_df.rename(columns = {0 : "title"})
    
#title_df

# %%
vote_average = []

for i in mymovies_df['vote_average']:
    pop1, pop2 = i
    vote_average.append(pop2)
    
    vote_average_df = pd.DataFrame(vote_average)
    
    vote_average_df = vote_average_df.rename(columns = {0 : "vote_average"})
    
    vote_average_df.replace(['Joker', 'Star Wars'], False, inplace=True)
    
    vote_average_df.replace( False, np.nan, inplace=True)
    
    
    
    
    
#vote_average_df

# %%
overview = []

for i in mymovies_df['overview']:
    pop1, pop2 = i
    overview.append(pop2)
    
    overview_df = pd.DataFrame(overview)
    
    overview_df = overview_df.rename(columns = {0 : "overview"})
    
#overview_df

# %%
release_date = []

for i in mymovies_df['release_date']:
    pop1, pop2 = i
    release_date.append(pop2)
    
    release_date_df = pd.DataFrame(release_date)
    
    release_date_df = release_date_df.rename(columns = {0 : "release_date"})
    
    release_date_df.replace('/udDclJoHjfjb8Ekgsd4FDteOkCU.jpg', '2019-10-02', inplace=True)
    release_date_df.replace('/btTdmkgIvOi0FFip1sPuZI2oQG6.jpg', '1977-05-25', inplace=True)

#release_date_df

# %%
movie_results = pd.concat([pop_col_df, vote_count_df, video_df, poster_path_df, id_df, adult_df, backdrop_path_df, original_language_df, 
                    original_title_df, title_df, vote_average_df, overview_df, release_date_df], axis = 1)

# %%
movie_results
# Out:
#     popularity  vote_count  video                       poster_path        id  \
# 0      622.987         959  False  /db32LaOibwEliAmSL2jjDF6oDdj.jpg  181812.0
# 8   False   /bga3i5jcejBekr2FCGJga1fYCh.jpg                en
# 9   False  /c6YyKddg8iVDYRRVZLDEd3m22RI.jpg                en
# 10  False   /jCCdt0e8Xe9ttvevD4S3TSMNdH.jpg                en
# 11  False                              None                tl
# 12  False  /mlaX4c2M6usnhXHG5sYJcKVXflA.jpg                id
# 13  False                        1977-05-25                en
# 14  False  /4K3GSYoDGJSnRRE5v3p9vhqVadu.jpg                en
# 15  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                en
# 16  False  /iGnCzXEx0cFlUbpyAMeHwHWhPhx.jpg                ja
# 17  False  /spYx9XQFODuqEVoPpvaJI1ksAVt.jpg                en
# 18  False  /nwoDC0IJA47wr3znJgT1kkk64Gy.jpg                en
# 19  False  /8moTOzunF7p40oR5XhlDvJckOSW.jpg                en
# 20  False  /raspMdRYIj0cCF6SQH8NQ1lLLMB.jpg                en
# 21  False  /ww5aGS5H2tUtckxFFNOJE2790S7.jpg                en
# 22  False  /rVqY0Bo4Npf6EIONUROxjYAJfmD.jpg                en
# 23  False  /nZ1N5tDpoNm8UJBmWGoTZCRiDoQ.jpg                en
# 24  False  /c2Ax8Rox5g6CneChwy1gmu4UbSb.jpg                en
# 25  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg                ko
# 26  False  /AbRYlvwAKHs0YuyNO6NX9ofq4l6.jpg                en
# 27  False                              None                en
# 28  False  /hziiv14OpD73u9gAak4XDDfBKa2.jpg                en
# 29  False  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg                en
# 30  False  /bOGkgRGdhrBYJSLpXaxhXVstddV.jpg                en
# 31  False  /5myQbDzw3l8K9yofUXRJ4UTVgam.jpg                en
# 32  False  /4F8M02OjkfDIIBg36R5ZluLK2nU.jpg                en
# 33  False  /qAhedRxRYWZAgZ8O8pHIl6QHdD7.jpg                en
# 34  False  /mSQjVoZJaZkaHpdLIahh04bfGDr.jpg                en
# 35  False  /re3ZvlKJg04iLpLRf1xTKHS2wLU.jpg                en
# 36  False  /s2bT29y0ngXxxu2IA8AOzzXTRhd.jpg                en
# 37  False  /ijiE9WoGSwSzM16zTxvUneJ8RXc.jpg                en
# 38  False  /stemLQMLDrlpfIlZ5OjllOPT8QX.jpg                en
# 39  False  /m67smI1IIMmYzCl9axvKNULVKLr.jpg                en
# 40  False  /j8uPZSPjKYzHlN2B4NhPQVWWZ5x.jpg                en
# 41  False  /5BmcysaAASA00FM0gRjD0ClMUY9.jpg                en
# 42  False  /tLCDKsXo6D84IVFanoElosSEKdp.jpg                en
# 43  False  /hbn46fQaRmlpBuUrEiFqv0GDL6Y.jpg                en
# 44  False  /iJlGxN0p1suzloBGvvBu3QSSlhT.jpg                en
# 45  False  /riTANvQ8GKmQbgtC1ps3OfkU43A.jpg                en
# 46  False  /uUiId6cG32JSRI6RyBQSvQtLjz2.jpg                en
# 47  False  /oFmzoKDMedABPpRBDVwr0aynSK1.jpg                en
# 48  False  /q1zsnEwcApz9AdMgV4nB0jrg1qg.jpg                en
# 49  False  /avqzwKn89VetTEvAlBePt3Us6Al.jpg                en
# 50  False  /ghQrKrcEpAlkzBuNoOCSxHQXWqw.jpg                en
# 51  False  /t3jTp49Yj0hDN5lghwD90M24Frs.jpg                en
# 52  False   /eGljNfNCrPhFYG2RXXmmE0OKu5.jpg                en
# 53  False  /xOKGkKwfK79xjmBd1EiIbPpc71k.jpg                en
# 54  False  /cjRUhKyt2Jo3V1KNzc5tpPNfccG.jpg                en
# 55  False  /9pGM43a9VmXxwIxmhJoiDkcB2hT.jpg                en
# 56  False  /iAX8lPlDEeGHatw79k1LfGLbTi2.jpg                en
# 57  False  /pIUvQ9Ed35wlWhY2oU6OmwEsmzG.jpg                en
# 58  False  /cN9Nbwh66TRcj2gBE8cSEZulsx3.jpg                en
# 59  False  /eP41pD4YfyVOjdpEaTmoNrL9DGx.jpg                en
#
#                                        original_title  \
# 0                    Star Wars: The Rise of Skywalker
# 1                                            Ad Astra
# 2                                               Joker
# 3                                                 葉問4
# 4                             Jumanji: The Next Level
# 5                                       6 Underground
# 6                                           Frozen II
# 7                                                Cars
# 8                      Red Shoes and the Seven Dwarfs
# 9                      Once Upon a Time… in Hollywood
# 10                             Zombieland: Double Tap
# 11                                      My Bakit List
# 12                                            Gundala
# 13                                          Star Wars
# 14                                               Togo
# 15                           Star Wars: The Last Jedi
# 16                                        ワンピーススタンピード
# 17                                  Rambo: Last Blood
# 18                                     Marriage Story
# 19                                     It Chapter Two
# 20                                             Code 8
# 21                                       The Irishman
# 22                                            Aladdin
# 23                                  Spies in Disguise
# 24                       Star Wars: The Force Awakens
# 25                                                기생충
# 26                                         Knives Out
# 27                    Emmanuelle, Queen of the Galaxy
# 28           Harry Potter and the Philosopher's Stone
# 29                                      The Lion King
# 30                             Avengers: Infinity War
# 31                          Spider-Man: Far from Home
# 32                                               Cats
# 33              Fast & Furious Presents: Hobbs & Shaw
# 34                                           Hustlers
# 35                         Steven Universe: The Movie
# 36                                          Inception
# 37                    El Camino: A Breaking Bad Movie
# 38                  John Wick: Chapter 3 - Parabellum
# 39                                        Toy Story 4
# 40                                       Ready or Not
# 41                                     The Lighthouse
# 42                                         Abominable
# 43                                       The Avengers
# 44                                          John Wick
# 45                              Terminator: Dark Fate
# 46                  Spider-Man: Into the Spider-Verse
# 47          Star Wars: Episode I - The Phantom Menace
# 48                            Solo: A Star Wars Story
# 49            Harry Potter and the Chamber of Secrets
# 50                                          Bombshell
# 51           The Princess Diaries 2: Royal Engagement
# 52                                         Uncut Gems
# 53                                          Insurgent
# 54                                       Dark Phoenix
# 55                                       Pulp Fiction
# 56                                        Seventh Son
# 57  The Lord of the Rings: The Fellowship of the Ring
# 58                                             Frozen
# 59                                             Casino
#
#                                                 title  vote_average  \
# 0                    Star Wars: The Rise of Skywalker           6.7
# 1                                            Ad Astra           6.0
# 2                    /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg           NaN
# 3                                Ip Man 4: The Finale           6.0
# 4                             Jumanji: The Next Level           6.7
# 5                                       6 Underground           6.3
# 6                                           Frozen II           7.0
# 7                                                Cars           6.7
# 8                      Red Shoes and the Seven Dwarfs           6.1
# 9                      Once Upon a Time… in Hollywood           7.5
# 10                             Zombieland: Double Tap           7.2
# 11                                      My Bakit List           7.0
# 12                                            Gundala           5.9
# 13                   /4iJfYYoQzZcONB9hNzg0J0wWyPH.jpg           NaN
# 14                                               Togo           6.8
# 15                           Star Wars: The Last Jedi           7.0
# 16                                One Piece: Stampede           7.4
# 17                                  Rambo: Last Blood           5.9
# 18                                     Marriage Story           8.1
# 19                                     It Chapter Two           6.8
# 20                                             Code 8           6.4
# 21                                       The Irishman           7.9
# 22                                            Aladdin           7.0
# 23                                  Spies in Disguise           8.4
# 24                       Star Wars: The Force Awakens           7.4
# 25                                           Parasite           8.6
# 26                                         Knives Out           7.9
# 27                    Emmanuelle, Queen of the Galaxy           3.4
# 28           Harry Potter and the Philosopher's Stone           7.8
# 29                                      The Lion King           7.1
# 30                             Avengers: Infinity War           8.3
# 31                          Spider-Man: Far from Home           7.6
# 32                                               Cats           5.2
# 33              Fast & Furious Presents: Hobbs & Shaw           6.5
# 34                                           Hustlers           6.2
# 35                         Steven Universe: The Movie           8.9
# 36                                          Inception           8.3
# 37                    El Camino: A Breaking Bad Movie           7.0
# 38                  John Wick: Chapter 3 - Parabellum           7.1
# 39                                        Toy Story 4           7.6
# 40                                       Ready or Not           6.8
# 41                                     The Lighthouse           8.1
# 42                                         Abominable           6.8
# 43                                       The Avengers           7.7
# 44                                          John Wick           7.2
# 45                              Terminator: Dark Fate           6.2
# 46                  Spider-Man: Into the Spider-Verse           8.4
# 47          Star Wars: Episode I - The Phantom Menace           6.4
# 48                            Solo: A Star Wars Story           6.6
# 49            Harry Potter and the Chamber of Secrets           7.7
# 50                                          Bombshell           6.8
# 51           The Princess Diaries 2: Royal Engagement           6.5
# 52                                         Uncut Gems           7.7
# 53                                          Insurgent           6.3
# 54                                       Dark Phoenix           6.1
# 55                                       Pulp Fiction           8.5
# 56                                        Seventh Son           5.3
# 57  The Lord of the Rings: The Fellowship of the Ring           8.3
# 58                                             Frozen           7.3
# 59                                             Casino           8.0
#
#                                              overview release_date
# 0   The surviving Resistance faces the First Order...   2019-12-18
# 1   The near future, a time when both hope and har...   2019-09-17
# 2   During the 1980s, a failed stand-up comedian i...   2019-10-02
# 3   Ip Man 4 is an upcoming Hong Kong biographical...   2019-12-20
# 4   As the gang return to Jumanji to rescue one of...   2019-12-04
# 5   After faking his death, a tech billionaire rec...   2019-12-13
# 6   Elsa, Anna, Kristoff and Olaf head far into th...   2019-11-20
# 7   Lightning McQueen, a hotshot rookie race car d...   2006-06-08
# 8   Princes who have been turned into Dwarfs seek ...   2019-07-25
# 9   Los Angeles, 1969. TV star Rick Dalton, a stru...   2019-07-25
# 10  Columbus, Tallahassee, Wichita, and Little Roc...   2019-10-09
# 11  Dess embarks on a soul searching journey and a...   2019-12-11
# 12  Sancaka has lived on the streets since his par...   2019-08-29
# 13  Princess Leia is captured and held hostage by ...   1977-05-25
# 14  The untold true story set in the winter of 192...   2019-12-20
# 15  Rey develops her newly discovered abilities wi...   2017-12-13
# 16  One Piece: Stampede is a stand-alone film that...   2019-08-09
# 17  After fighting his demons for decades, John Ra...   2019-09-19
# 18  A stage director and an actress struggle throu...   2019-11-06
# 19  27 years after overcoming the malevolent super...   2019-09-04
# 20  In Lincoln City, some inhabitants have extraor...   2019-12-06
# 21  Pennsylvania, 1956. Frank Sheeran, a war veter...   2019-11-01
# 22  A kindhearted street urchin named Aladdin emba...   2019-05-22
# 23  When the world's best spy is turned into a pig...   2019-12-24
# 24  Thirty years after defeating the Galactic Empi...   2015-12-15
# 25  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 26  When renowned crime novelist Harlan Thrombey i...   2019-11-27
# 27  Emmanuelle shows a group of aliens the art of ...   1994-02-07
# 28  Harry Potter has lived under the stairs at his...   2001-11-16
# 29  Simba idolizes his father, King Mufasa, and ta...   2019-07-12
# 30  As the Avengers and their allies have continue...   2018-04-25
# 31  Peter Parker and his friends go on a summer tr...   2019-06-28
# 32  A tribe of cats called the Jellicles must deci...   2019-12-19
# 33  Ever since US Diplomatic Security Service Agen...   2019-08-01
# 34  A crew of savvy former strip club employees ba...   2019-09-12
# 35  Two years after the events of "Change Your Min...   2019-09-02
# 36  Cobb, a skilled thief who commits corporate es...   2010-07-15
# 37  In the wake of his dramatic escape from captiv...   2019-10-11
# 38  Super-assassin John Wick returns with a $14 mi...   2019-05-15
# 39  Woody has always been confident about his plac...   2019-06-19
# 40  A bride's wedding night takes a sinister turn ...   2019-08-21
# 41  Two lighthouse keepers try to maintain their s...   2019-10-18
# 42  A group of misfits encounter a young Yeti name...   2019-09-19
# 43  When an unexpected enemy emerges and threatens...   2012-04-25
# 44  Ex-hitman John Wick comes out of retirement to...   2014-10-22
# 45  Decades after Sarah Connor prevented Judgment ...   2019-10-23
# 46  Miles Morales is juggling his life between bei...   2018-12-06
# 47  Anakin Skywalker, a young slave strong with th...   1999-05-19
# 48  Through a series of daring escapades deep with...   2018-05-15
# 49  Cars fly, trees fight back, and a mysterious h...   2002-11-13
# 50  Bombshell is a revealing look inside the most ...   2019-12-13
# 51  Mia Thermopolis is now a college graduate and ...   2004-08-06
# 52  Howard Ratner, a charismatic New York City jew...   2019-12-13
# 53  Beatrice Prior must confront her inner demons ...   2015-03-18
# 54  The X-Men face their most formidable and power...   2019-06-05
# 55  A burger-loving hit man, his philosophical par...   1994-09-10
# 56  John Gregory, who is a seventh son of a sevent...   2014-12-12
# 57  Young hobbit Frodo Baggins, after inheriting a...   2001-12-18
# 58  Young princess Anna of Arendelle dreams about ...   2013-11-27
# 59  In early-1970s Las Vegas, low-level mobster Sa...   1995-11-22

# %%
cols = []
for col in movie_results.columns:
    col = str(col)
    cols.append(col.lower())
movie_results.columns = cols
cols
# Out:
# ['popularity',
#  'vote_count',
#  'video',
#  'poster_path',
#  'id',
#  'adult',
#  'backdrop_path',
#  'original_language',
#  'original_title',
#  'title',
#  'vote_average',
#  'overview',
#  'release_date']

# %%
rds_connection_string = "postgres:Dbadmin@localhost:5432/ODBM_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['movies']

# %%
movie_results.to_sql(name='movies', con=engine, if_exists='append', index=False)
